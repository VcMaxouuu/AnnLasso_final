# %%
from models import AnnLassoRegression, AnnLassoClassification, LinearModel # Available models
import utils
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import torch

# %%
X = np.random.normal(size = (5000, 50)) # Create random X set or use one in data folder -- X = pd.read_csv("path")
y, s = utils.generate_nonlinear_data(X, 2) # utils.generate_linear_data(X, s) for linear -- s = features number

model = AnnLassoRegression(penalty = 0, p2=20) # penalty = 1 for l1, 0 for non convex, Use lambda_qut = ... if lambda pre computed
model.fit(X,y, True, True) # fit method takes X and y -- First True if verbose or not -- Second True if saving first layer evolutions
# Out:
# Lambda = 0.8821 -- Nu = 1
# 	Epoch: 0 | Loss: 10469.28320 | learning rate : 0.100000
# 	Epoch: 20 | Loss: 3259.50684 | learning rate : 0.100000
# 	Epoch: 40 | Loss: 575.76727 | learning rate : 0.100000
# 	Epoch: 60 | Loss: 332.76678 | learning rate : 0.053144
# 	Epoch: 80 | Loss: 246.01416 | learning rate : 0.053144
# 	Epoch: 100 | Loss: 208.40903 | learning rate : 0.053144
# 	Epoch: 120 | Loss: 181.95230 | learning rate : 0.053144
# 	Epoch: 140 | Loss: 153.82690 | learning rate : 0.016677
# 	Epoch: 160 | Loss: 152.24698 | learning rate : 0.016677
# 	Epoch: 180 | Loss: 151.03271 | learning rate : 0.016677
# 	Epoch: 200 | Loss: 149.80371 | learning rate : 0.016677
# 	Epoch: 220 | Loss: 148.23039 | learning rate : 0.016677
# 	Epoch: 240 | Loss: 146.72382 | learning rate : 0.016677
# 	Epoch: 260 | Loss: 145.33246 | learning rate : 0.016677
# 	Epoch: 280 | Loss: 144.26965 | learning rate : 0.016677
# 	Epoch: 300 | Loss: 143.38446 | learning rate : 0.016677
# ...

# %%
print(model.important_features, s) # important features returns tuple (n_features, indexes)
# Out:
# (2, [4, 18]) [18  4]

# %%
model.layer1_evolution() # generates a gif of first layer evolutions
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
# ...

# %%
model.layer1_simplified.weight.data # Returns the non zero columns of first layer
# Out:
# tensor([[  0.0000,   0.0000],
#         [  0.0000,  28.9058],
#         [  0.0000,   0.0000],
#         [  0.0000,   0.0000],
#         [  0.0000,   0.0000],
#         [  0.0000,   0.0000],
#         [  0.0000,   0.0000],
#         [-16.1511,   0.0000],
#         [  0.0000,   0.0000],
#         [  0.0000,   0.0000],
#         [  0.0000, -17.0960],
#         [  0.0000,   0.0000],
#         [  0.0000,   0.0000],
#         [  0.0000,   0.0000],
#         [  0.0000,   0.0000],
#         [  0.0000,   0.0000],
#         [ 28.3397,   0.0000],
#         [  0.0000,   0.0000],
#         [  0.0000,   0.0000],
#         [  0.0000,   0.0000]])
